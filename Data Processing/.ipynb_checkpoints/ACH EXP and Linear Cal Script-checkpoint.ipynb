# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from sklearn.metrics import r2_score
from pptx import Presentation
from pptx.util import Inches

# %%
# Define the exponential function
def exponential_function(x, a, b):
    return a * np.exp(b * x)

def linear_function(x,a,b):
    return a*x + b

def save_plot_as_image(time_column, pm25_column, fitted_pm25, params, filename):
    plt.figure(figsize=(10, 6))
    plt.scatter(time_column, pm25_column, label='Original Data')
    plt.plot(time_column, fitted_pm25, label='Fitted Curve', color='red')
    plt.xlabel('Time')
    plt.ylabel('PM 2.5')
    plt.title('Fitted Curve of PM 2.5 Data' + filename)
    plt.legend()
#     image_path = f"{filename}.png"
#     plt.savefig(image_path)
    plt.show()
#     return image_path

def cal_stats(time_column, pm25_column,ln_pm25_column):
    # Perform curve fitting using curve_fit
    params, covariance = curve_fit(exponential_function, time_column, pm25_column)
    
    params_l, covariance_l = curve_fit(linear_function, time_column, ln_pm25_column)

    # Calculate the fitted values using the obtained parameters
    fitted_pm25 = exponential_function(time_column, *params)
    
    liner_fiited_pm25 = linear_function(time_column, *params_l)

    # Calculate the R-squared value
    r_squared = r2_score(pm25_column, fitted_pm25)
    
    r_squared_l = r2_score(ln_pm25_column, liner_fiited_pm25)

#     save_plot_as_image(time_column,pm25_column,fitted_pm25,params,'Exponetial//45//'+image_name+ ' expoential')
#     save_plot_as_image(time_column,ln_pm25_column,liner_fiited_pm25,params_l,'Linear//45//' + image_name + ' linear')
    return abs(params[1]),r_squared,abs(params_l[0]),r_squared_l

def exponetial_fit(file_path,image_name = ''):
    df = pd.read_csv(file_path)
    time_column = df['Time In Hour']
    pm25_column = df['PM 2.5']
    ln_pm25_column = df['LN(PM 2.5)']
    

    params,r_squared,params_l,r_squared_l = cal_stats(time_column, pm25_column,ln_pm25_column)

    
    if r_squared < 0.95 or  r_squared_l < 0.95:
        print(file_path)
        print('Before :::: \n EX R Square:- ', r_squared, '\n LN R Square:- ', r_squared_l, '\n Diff:- ', abs(params-params_l))
        tolerance = 30
        df['PercentageChange'] = df['PM 2.5'].pct_change() * 100 
        
        df['WithinTolerance'] = (df['PercentageChange'].shift(-1) <= tolerance) | df['PercentageChange'].isna()
        
        index_to_slice = df[df['WithinTolerance'] == False].index[0] 
#         print(index_to_slice)
#         df.to_csv('text.csv')
        pm25_column = df.loc[:index_to_slice, 'PM 2.5']
        time_column = df.loc[:index_to_slice, 'Time In Hour']
        ln_pm25_column = df.loc[:index_to_slice, 'LN(PM 2.5)']
#         print(len(pm25_column), ':', len(time_column), ':', len(ln_pm25_column))
        params,r_squared,params_l,r_squared_l = cal_stats(time_column, pm25_column,ln_pm25_column)
        print('After :::: \n EX R Square:- ', r_squared, '\n LN R Square:- ', r_squared_l, '\n Diff:- ', abs(params-params_l),'\n')
    
    return params,r_squared,params_l,r_squared_l

# %%
folders = ['C:\\Users\\vrana7\\Documents\\CIA\\Humidifier-Experiment\\CBHS\\Processed\\',
           'C:\\Users\\vrana7\\Documents\\CIA\\Humidifier-Experiment\\RDRK\\Processed\\']
cr = [ '12-23', '1-13', '1-27', '2-10', '2-24', '3-10', '3-24', '4-7','4-21','4-28', '5-5', '5-12','5-19', '2-16', '2-20', '2-22' ]

ex_ach_list = []
ln_ach_list = []
ex_r_list = []
ln_r_list = []
date_list = []
id_list = []

ex_ach_list_w = []
ln_ach_list_w = []
ex_r_list_w = []
ln_r_list_w = []
date_list_w = []
id_list_w = []
for folder in folders:
    subfolders = [f for f in os.listdir(folder) if os.path.isdir(os.path.join(folder, f))]

    
    for subfolder in subfolders:
        path = folder + '\\' +subfolder 
        files = [f for f in os.listdir(path) if f.lower().endswith(('.csv'))]
        for file in files:
            exACH,exR,lnACH,lnR = exponetial_fit(path+'\\'+file)
            date = file.split('-')[3] + '-' + file.split('-')[4].split('.')[0]
            date_string = date + ('-2023' if file.split('-')[3] != '12' else '-2022')
            date_object = pd.to_datetime(date_string, format='%m-%d-%Y')
            if date in cr:
                ex_ach_list.append(exACH)
                ln_ach_list.append(lnACH)
                ex_r_list.append(exR)
                ln_r_list.append(lnR)
                date_list.append(date_object)
                id_list.append(subfolder)
            else: 
                ex_ach_list_w.append(exACH)
                ln_ach_list_w.append(lnACH)
                ex_r_list_w.append(exR)
                ln_r_list_w.append(lnR)
                date_list_w.append(date_object)
                id_list_w.append(subfolder)
                
data = {
  'ID' : id_list,
  'ACH Exponetial Fit' : ex_ach_list ,
  'R Sqaure Exponetial Fit' : ex_r_list,
  'ACH Linear Fit' : ln_ach_list,
  'R Square Linear Fit' : ln_r_list,
  'Date' : date_list,
  'Diff ACH' : np.abs(np.array(ex_ach_list)-np.array(ln_ach_list))
} 

data_w = {
  'ID' : id_list_w,
  'ACH Exponetial Fit' : ex_ach_list_w,
  'R Sqaure Exponetial Fit' : ex_r_list_w,
  'ACH Linear Fit' : ln_ach_list_w,
  'R Square Linear Fit' : ln_r_list_w,
  'Date' : date_list_w,
  'Diff ACH' : np.abs(np.array(ex_r_list_w)-np.array(ln_r_list_w))
}                 
        
df = pd.DataFrame(data)
df_w = pd.DataFrame(data_w)


df.to_csv('ACH with C-R.csv',index=False)

df_w.to_csv('ACH without C-R.csv',index=False)
# Out:
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\10\MOD-PM-00580-1-12.csv
# Before ::::
#  EX R Square:-  0.9191734484433784
#  LN R Square:-  0.8849286930026171
#  Diff:-  3.265687822950799
# After ::::
#  EX R Square:-  0.9272980245438788
#  LN R Square:-  0.9561069070423356
#  Diff:-  2.650755458141175
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\10\MOD-PM-00580-12-18.csv
# Before ::::
#  EX R Square:-  0.662869702119015
#  LN R Square:-  0.6062833726670422
#  Diff:-  0.49285267354805706
# After ::::
#  EX R Square:-  0.90757186357414
#  LN R Square:-  0.8590008947033725
#  Diff:-  0.6236326577216722
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\10\MOD-PM-00580-2-23.csv
# Before ::::
#  EX R Square:-  0.9745427817592718
#  LN R Square:-  0.8473145466182695
#  Diff:-  0.5365294667153382
# After ::::
#  EX R Square:-  0.9978511669784657
#  LN R Square:-  0.9953103210542823
#  Diff:-  0.08667949992883361
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\10\MOD-PM-00580-2-9.csv
# Before ::::
#  EX R Square:-  0.9324924207331179
#  LN R Square:-  0.856514153700715
#  Diff:-  2.5081372427458946
# After ::::
#  EX R Square:-  0.9382542745541651
#  LN R Square:-  0.9774078949142769
#  Diff:-  1.9494063911067023
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\10\MOD-PM-00580-5-18.csv
# Before ::::
#  EX R Square:-  0.8966962803044953
#  LN R Square:-  0.9679795738323045
#  Diff:-  6.834134669265067
# After ::::
#  EX R Square:-  0.8936205339318282
#  LN R Square:-  0.9696703850860837
#  Diff:-  6.698175515309341
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\14\MOD-PM-00584-1-12.csv
# Before ::::
#  EX R Square:-  0.8792834154225694
#  LN R Square:-  0.9170515823114362
#  Diff:-  4.093574160313613
# After ::::
#  EX R Square:-  0.8732464735179872
#  LN R Square:-  0.9176886607601227
#  Diff:-  3.5410510189360638
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\14\MOD-PM-00584-1-26.csv
# Before ::::
#  EX R Square:-  0.8975075419234491
#  LN R Square:-  0.9192764803420845
#  Diff:-  2.2378870147846643
# After ::::
#  EX R Square:-  0.7505060410732628
#  LN R Square:-  0.58068809939714
#  Diff:-  3.0173206506388794
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\14\MOD-PM-00584-1-27.csv
# Before ::::
#  EX R Square:-  0.9761793764244822
#  LN R Square:-  0.9429792904326518
#  Diff:-  4.6503514535002335
# After ::::
#  EX R Square:-  0.9761793764244822
#  LN R Square:-  0.9429792904326518
#  Diff:-  4.6503514535002335
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\14\MOD-PM-00584-11-28.csv
# Before ::::
#  EX R Square:-  0.8946956999694125
#  LN R Square:-  0.9259372831407116
#  Diff:-  1.3277839117549814
# After ::::
#  EX R Square:-  0.8946956999694125
#  LN R Square:-  0.9259372831407116
#  Diff:-  1.3277839117549814
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\14\MOD-PM-00584-12-22.csv
# Before ::::
#  EX R Square:-  0.9245583248983371
#  LN R Square:-  0.93254146492897
#  Diff:-  0.645476284751378
# After ::::
#  EX R Square:-  0.929212065320778
#  LN R Square:-  0.9442502172152704
#  Diff:-  0.591668937222928
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\14\MOD-PM-00584-2-10.csv
# Before ::::
#  EX R Square:-  0.9374547064373038
#  LN R Square:-  0.9626299391483428
#  Diff:-  5.479475771625603
# After ::::
#  EX R Square:-  0.9374547064373038
#  LN R Square:-  0.9626299391483428
#  Diff:-  5.479475771625603
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\14\MOD-PM-00584-2-23.csv
# Before ::::
#  EX R Square:-  0.9168568609938309
#  LN R Square:-  0.9181807610299927
#  Diff:-  3.705378606324882
# After ::::
#  EX R Square:-  0.9168568609938309
#  LN R Square:-  0.9181807610299927
#  Diff:-  3.705378606324882
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\14\MOD-PM-00584-2-24.csv
# Before ::::
#  EX R Square:-  0.856785556993584
#  LN R Square:-  0.877518118922393
#  Diff:-  3.99678151347788
# After ::::
#  EX R Square:-  0.856785556993584
#  LN R Square:-  0.877518118922393
#  Diff:-  3.99678151347788
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\14\MOD-PM-00584-2-9.csv
# Before ::::
#  EX R Square:-  0.937038108323749
#  LN R Square:-  0.9635801056212818
#  Diff:-  1.7654855028571474
# After ::::
#  EX R Square:-  0.937038108323749
#  LN R Square:-  0.9635801056212818
#  Diff:-  1.7654855028571474
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\14\MOD-PM-00584-3-10.csv
# Before ::::
#  EX R Square:-  0.920575466141804
#  LN R Square:-  0.9350294490533322
#  Diff:-  3.755859560008682
# After ::::
#  EX R Square:-  0.920575466141804
#  LN R Square:-  0.9350294490533322
#  Diff:-  3.755859560008682
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\14\MOD-PM-00584-3-23.csv
# Before ::::
#  EX R Square:-  0.9344076498728534
#  LN R Square:-  0.916742211562898
#  Diff:-  7.963029215410695
# After ::::
#  EX R Square:-  0.9344076498728534
#  LN R Square:-  0.916742211562898
#  Diff:-  7.963029215410695
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\14\MOD-PM-00584-4-06.csv
# Before ::::
#  EX R Square:-  0.9472979036393374
#  LN R Square:-  0.9193647078950573
#  Diff:-  3.462452254786822
# After ::::
#  EX R Square:-  0.9373909440772611
#  LN R Square:-  0.9461690319738456
#  Diff:-  2.3119774065800325
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\14\MOD-PM-00584-4-07.csv
# Before ::::
#  EX R Square:-  0.9022576551123522
#  LN R Square:-  0.9676319795427997
#  Diff:-  0.1429742814760564
# After ::::
#  EX R Square:-  0.9022576551123522
#  LN R Square:-  0.9676319795427997
#  Diff:-  0.1429742814760564
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\14\MOD-PM-00584-4-20.csv
# Before ::::
#  EX R Square:-  0.9419655378005047
#  LN R Square:-  0.9412106736783113
#  Diff:-  3.485284687648241
# After ::::
#  EX R Square:-  0.9396818727022462
#  LN R Square:-  0.9468334976782761
#  Diff:-  3.246695790686119
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\14\MOD-PM-00584-4-21.csv
# Before ::::
#  EX R Square:-  0.9046303355730061
#  LN R Square:-  0.9584700949370358
#  Diff:-  14.640319092198467
# After ::::
#  EX R Square:-  0.9046303355730061
#  LN R Square:-  0.9584700949370358
#  Diff:-  14.640319092198467
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\14\MOD-PM-00584-5-11.csv
# Before ::::
#  EX R Square:-  0.8351648170835011
#  LN R Square:-  0.9071351182643013
#  Diff:-  14.030812958238284
# After ::::
#  EX R Square:-  0.8351648170835011
#  LN R Square:-  0.9071351182643013
#  Diff:-  14.030812958238284
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\14\MOD-PM-00584-5-12.csv
# Before ::::
#  EX R Square:-  0.9409072613380667
#  LN R Square:-  0.8974460536358765
#  Diff:-  12.731984469082619
# After ::::
#  EX R Square:-  0.9409072613380667
#  LN R Square:-  0.8974460536358765
#  Diff:-  12.731984469082619
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\14\MOD-PM-00584-5-18.csv
# Before ::::
#  EX R Square:-  0.9356270253294535
#  LN R Square:-  0.9640371834332817
#  Diff:-  1.081198292105007
# After ::::
#  EX R Square:-  0.9356270253294535
#  LN R Square:-  0.9640371834332817
#  Diff:-  1.081198292105007
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\14\MOD-PM-00584-5-19.csv
# Before ::::
#  EX R Square:-  0.9848034642635621
#  LN R Square:-  0.9414163902623714
#  Diff:-  3.8596541402491145
# After ::::
#  EX R Square:-  0.9846755363721036
#  LN R Square:-  0.9459099504252144
#  Diff:-  3.6962953018373055
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\14\MOD-PM-00584-5-4.csv
# Before ::::
#  EX R Square:-  0.9019524238512352
#  LN R Square:-  0.9700778850053221
#  Diff:-  3.1257442089881176
# After ::::
#  EX R Square:-  0.9019524238512352
#  LN R Square:-  0.9700778850053221
#  Diff:-  3.1257442089881176
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\14\MOD-PM-00584-5-5.csv
# Before ::::
#  EX R Square:-  0.9183907125403482
#  LN R Square:-  0.9711212386890704
#  Diff:-  10.113367223114537
# After ::::
#  EX R Square:-  0.9183907125403482
#  LN R Square:-  0.9711212386890704
#  Diff:-  10.113367223114537
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\15\MOD-PM-00585-2-9.csv
# Before ::::
#  EX R Square:-  0.9923814973959593
#  LN R Square:-  0.9261359666427347
#  Diff:-  0.5699790531055413
# After ::::
#  EX R Square:-  0.9939462946562685
#  LN R Square:-  0.924968410059219
#  Diff:-  0.37738066992998065
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\15\MOD-PM-00585-5-4.csv
# Before ::::
#  EX R Square:-  0.9410280070474405
#  LN R Square:-  0.05258181944469975
#  Diff:-  2.9645614377300813
# After ::::
#  EX R Square:-  0.9864792697316135
#  LN R Square:-  0.9875730853771183
#  Diff:-  0.61452092152759
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\16\MOD-PM-00586-1-12.csv
# Before ::::
#  EX R Square:-  0.9085574268464457
#  LN R Square:-  0.9352031703325561
#  Diff:-  0.9501726168967453
# After ::::
#  EX R Square:-  0.3093219775058099
#  LN R Square:-  0.29689159152520006
#  Diff:-  0.11581798863525639
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\16\MOD-PM-00586-1-13.csv
# Before ::::
#  EX R Square:-  0.9509829447089538
#  LN R Square:-  0.861720028607628
#  Diff:-  3.117312794128227
# After ::::
#  EX R Square:-  0.9502511127447261
#  LN R Square:-  0.9352198350573109
#  Diff:-  1.9090700555838223
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\16\MOD-PM-00586-1-26.csv
# Before ::::
#  EX R Square:-  0.9621526983622093
#  LN R Square:-  0.9279244042089617
#  Diff:-  1.4438847106703885
# After ::::
#  EX R Square:-  0.9631012256385211
#  LN R Square:-  0.9420713235997145
#  Diff:-  1.1439030618175585
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\16\MOD-PM-00586-1-27.csv
# Before ::::
#  EX R Square:-  0.9518072520188567
#  LN R Square:-  0.9099403423989066
#  Diff:-  1.391691600272557
# After ::::
#  EX R Square:-  0.9582091992653302
#  LN R Square:-  0.9340172690641565
#  Diff:-  1.2088803102995551
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\16\MOD-PM-00586-12-11.csv
# Before ::::
#  EX R Square:-  0.5942778555237231
#  LN R Square:-  0.704552051791857
#  Diff:-  0.46997978484749336
# After ::::
#  EX R Square:-  0.5942778555237231
#  LN R Square:-  0.704552051791857
#  Diff:-  0.46997978484749336
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\16\MOD-PM-00586-12-22.csv
# Before ::::
#  EX R Square:-  0.9025773455585906
#  LN R Square:-  0.8955260275918107
#  Diff:-  0.8517247547107585
# After ::::
#  EX R Square:-  0.9025773455585906
#  LN R Square:-  0.8955260275918107
#  Diff:-  0.8517247547107585
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\16\MOD-PM-00586-12-23.csv
# Before ::::
#  EX R Square:-  0.9437218303464256
#  LN R Square:-  0.8976259634355105
#  Diff:-  1.14593590202605
# After ::::
#  EX R Square:-  0.9437218303464256
#  LN R Square:-  0.8976259634355105
#  Diff:-  1.14593590202605
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\16\MOD-PM-00586-2-10.csv
# Before ::::
#  EX R Square:-  0.9885667407730843
#  LN R Square:-  0.9475674952069857
#  Diff:-  1.941337506998574
# After ::::
#  EX R Square:-  0.9899692914678374
#  LN R Square:-  0.9788153507466851
#  Diff:-  0.8706973264804869
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\16\MOD-PM-00586-2-23.csv
# Before ::::
#  EX R Square:-  0.9462015719205301
#  LN R Square:-  0.9444408171791283
#  Diff:-  1.1636314810855346
# After ::::
#  EX R Square:-  0.9491164367347112
#  LN R Square:-  0.9508425374910513
#  Diff:-  1.0493357566293238
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\16\MOD-PM-00586-2-24.csv
# Before ::::
#  EX R Square:-  0.972850732410141
#  LN R Square:-  0.9377518405206611
#  Diff:-  1.8511927854845678
# After ::::
#  EX R Square:-  0.972850732410141
#  LN R Square:-  0.9377518405206611
#  Diff:-  1.8511927854845678
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\16\MOD-PM-00586-2-9.csv
# Before ::::
#  EX R Square:-  0.9614579296527848
#  LN R Square:-  0.9358935964023475
#  Diff:-  1.2669808898038113
# After ::::
#  EX R Square:-  0.9703807539070339
#  LN R Square:-  0.961023454185608
#  Diff:-  0.6456574149992469
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\16\MOD-PM-00586-3-09.csv
# Before ::::
#  EX R Square:-  0.9618816748530918
#  LN R Square:-  0.9090995931042914
#  Diff:-  1.688310129514548
# After ::::
#  EX R Square:-  0.9700916536643024
#  LN R Square:-  0.9434525791482452
#  Diff:-  1.2300726854834303
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\16\MOD-PM-00586-3-10.csv
# Before ::::
#  EX R Square:-  0.9762514755777679
#  LN R Square:-  0.92725847849486
#  Diff:-  2.7257421554504146
# After ::::
#  EX R Square:-  0.9762514755777679
#  LN R Square:-  0.92725847849486
#  Diff:-  2.7257421554504146
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\16\MOD-PM-00586-3-23.csv
# Before ::::
#  EX R Square:-  0.9080923129575309
#  LN R Square:-  0.787994436153032
#  Diff:-  0.9728106847630891
# After ::::
#  EX R Square:-  0.9754062695250046
#  LN R Square:-  0.9634670970161819
#  Diff:-  0.4979080981873758
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\16\MOD-PM-00586-3-24.csv
# Before ::::
#  EX R Square:-  0.9626861780824194
#  LN R Square:-  0.928018381276059
#  Diff:-  1.589601694184264
# After ::::
#  EX R Square:-  0.9626861780824194
#  LN R Square:-  0.928018381276059
#  Diff:-  1.589601694184264
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\16\MOD-PM-00586-4-06.csv
# Before ::::
#  EX R Square:-  0.8940747302377661
#  LN R Square:-  0.6852186861104199
#  Diff:-  2.0449057854888624
# After ::::
#  EX R Square:-  0.94933905164101
#  LN R Square:-  0.912882657091433
#  Diff:-  1.128134632911654
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\16\MOD-PM-00586-5-11.csv
# Before ::::
#  EX R Square:-  0.9815418221793285
#  LN R Square:-  0.9156835958552808
#  Diff:-  1.7234950009338537
# After ::::
#  EX R Square:-  0.9815418221793285
#  LN R Square:-  0.9156835958552808
#  Diff:-  1.7234950009338537
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\16\MOD-PM-00586-5-18.csv
# Before ::::
#  EX R Square:-  0.970132379710774
#  LN R Square:-  0.8330992966427622
#  Diff:-  2.4038429671016313
# After ::::
#  EX R Square:-  0.9788831964811177
#  LN R Square:-  0.9289838688556824
#  Diff:-  1.7610519978629315
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\16\MOD-PM-00586-5-19.csv
# Before ::::
#  EX R Square:-  0.9554217965593859
#  LN R Square:-  0.8622915402302899
#  Diff:-  3.5184965182700645
# After ::::
#  EX R Square:-  0.9554217965593859
#  LN R Square:-  0.8622915402302899
#  Diff:-  3.5184965182700645
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\16\MOD-PM-00586-5-4.csv
# Before ::::
#  EX R Square:-  0.9688210267618712
#  LN R Square:-  0.9226171038580727
#  Diff:-  1.8939572080495246
# After ::::
#  EX R Square:-  0.974258088491435
#  LN R Square:-  0.9456067694872118
#  Diff:-  1.362837054122764
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\16\MOD-PM-00586-5-5.csv
# Before ::::
#  EX R Square:-  0.9850405057326866
#  LN R Square:-  0.94675225343612
#  Diff:-  1.9063687350876743
# After ::::
#  EX R Square:-  0.9886255905785121
#  LN R Square:-  0.9726893455149721
#  Diff:-  1.0008612445417908
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\18\MOD-PM-00588-12-11.csv
# Before ::::
#  EX R Square:-  0.9582794580249154
#  LN R Square:-  0.9292390162420885
#  Diff:-  0.3410466162695174
# After ::::
#  EX R Square:-  0.9582794580249154
#  LN R Square:-  0.9292390162420885
#  Diff:-  0.3410466162695174
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\19\MOD-PM-00590-12-11.csv
# Before ::::
#  EX R Square:-  0.8227080146331511
#  LN R Square:-  0.825256774247953
#  Diff:-  0.00964641154972784
# After ::::
#  EX R Square:-  0.8227080146331511
#  LN R Square:-  0.825256774247953
#  Diff:-  0.00964641154972784
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\19\MOD-PM-00590-2-24.csv
# Before ::::
#  EX R Square:-  0.9317103464569549
#  LN R Square:-  0.9550959834400193
#  Diff:-  0.6219692400107757
# After ::::
#  EX R Square:-  0.9317103464569549
#  LN R Square:-  0.9550959834400193
#  Diff:-  0.6219692400107757
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\19\MOD-PM-00590-3-09.csv
# Before ::::
#  EX R Square:-  0.9634065931789262
#  LN R Square:-  0.8442510984823461
#  Diff:-  1.846238725984772
# After ::::
#  EX R Square:-  0.992600973004674
#  LN R Square:-  0.9828995739910961
#  Diff:-  0.4237308344223534
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\20\MOD-PM-00591-12-11.csv
# Before ::::
#  EX R Square:-  0.9085733419816172
#  LN R Square:-  0.8851381871993887
#  Diff:-  0.1277105014011668
# After ::::
#  EX R Square:-  0.9085733419816172
#  LN R Square:-  0.8851381871993887
#  Diff:-  0.1277105014011668
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\20\MOD-PM-00591-3-23.csv
# Before ::::
#  EX R Square:-  0.9688006162904824
#  LN R Square:-  0.8529377507283059
#  Diff:-  0.7355959804030228
# After ::::
#  EX R Square:-  0.9919155001802525
#  LN R Square:-  0.9919784174045486
#  Diff:-  0.27773103040723424
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\20\MOD-PM-00591-5-11.csv
# Before ::::
#  EX R Square:-  0.9838379348755222
#  LN R Square:-  0.9165974819427422
#  Diff:-  1.0979084750526757
# After ::::
#  EX R Square:-  0.9880023090971175
#  LN R Square:-  0.9896549231320496
#  Diff:-  0.556188504758627
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\22\MOD-PM-00591-11-28.csv
# Before ::::
#  EX R Square:-  0.9507419201551649
#  LN R Square:-  0.9335744611338941
#  Diff:-  0.06858716927336683
# After ::::
#  EX R Square:-  0.9507419201551649
#  LN R Square:-  0.9335744611338941
#  Diff:-  0.06858716927336683
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\22\MOD-PM-00593-12-22.csv
# Before ::::
#  EX R Square:-  0.9476846083883864
#  LN R Square:-  0.9312921163288524
#  Diff:-  0.06196004782981279
# After ::::
#  EX R Square:-  0.9476846083883864
#  LN R Square:-  0.9312921163288524
#  Diff:-  0.06196004782981279
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\22\MOD-PM-00593-12-23.csv
# Before ::::
#  EX R Square:-  0.9212843964552789
#  LN R Square:-  0.9285080933711556
#  Diff:-  0.023131287514809085
# After ::::
#  EX R Square:-  0.9212843964552789
#  LN R Square:-  0.9285080933711556
#  Diff:-  0.023131287514809085
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\22\MOD-PM-00593-2-24.csv
# Before ::::
#  EX R Square:-  0.9479000711044001
#  LN R Square:-  0.972591141198223
#  Diff:-  0.6826194116394975
# After ::::
#  EX R Square:-  0.9479000711044001
#  LN R Square:-  0.972591141198223
#  Diff:-  0.6826194116394975
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\22\MOD-PM-00593-3-09.csv
# Before ::::
#  EX R Square:-  0.939022773240525
#  LN R Square:-  0.8659038175917648
#  Diff:-  1.00861618507329
# After ::::
#  EX R Square:-  0.939022773240525
#  LN R Square:-  0.8659038175917648
#  Diff:-  1.00861618507329
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\22\MOD-PM-00593-3-10.csv
# Before ::::
#  EX R Square:-  0.8018118114659342
#  LN R Square:-  0.7633032115907694
#  Diff:-  4.228915892599007
# After ::::
#  EX R Square:-  0.8018118114659342
#  LN R Square:-  0.7633032115907694
#  Diff:-  4.228915892599007
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\22\MOD-PM-00593-4-06.csv
# Before ::::
#  EX R Square:-  0.9888934216296752
#  LN R Square:-  0.9460449323387587
#  Diff:-  1.5623456849080806
# After ::::
#  EX R Square:-  0.9893304623234336
#  LN R Square:-  0.9511963316163898
#  Diff:-  1.4565272994686742
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\22\MOD-PM-00593-4-27.csv
# Before ::::
#  EX R Square:-  0.983790340493261
#  LN R Square:-  0.9302823097587724
#  Diff:-  2.007384320643931
# After ::::
#  EX R Square:-  0.9847280185778552
#  LN R Square:-  0.9402304418865345
#  Diff:-  1.7599802719507132
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\22\MOD-PM-00593-4-28.csv
# Before ::::
#  EX R Square:-  0.9936106703908959
#  LN R Square:-  0.9444677461747221
#  Diff:-  2.291006359563889
# After ::::
#  EX R Square:-  0.9947108450136721
#  LN R Square:-  0.9701408609819047
#  Diff:-  1.3441601996006938
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\22\MOD-PM-00593-5-11.csv
# Before ::::
#  EX R Square:-  0.9702729009967984
#  LN R Square:-  0.8981298854564306
#  Diff:-  1.270094268177024
# After ::::
#  EX R Square:-  0.9828579277923601
#  LN R Square:-  0.9609561836684505
#  Diff:-  0.7086711578504672
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\22\MOD-PM-00593-5-12.csv
# Before ::::
#  EX R Square:-  0.9381847731471843
#  LN R Square:-  0.8558046363287346
#  Diff:-  2.4009206948940345
# After ::::
#  EX R Square:-  0.9381847731471843
#  LN R Square:-  0.8558046363287346
#  Diff:-  2.4009206948940345
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\22\MOD-PM-00593-5-18.csv
# Before ::::
#  EX R Square:-  0.9957497930606567
#  LN R Square:-  0.9341806497364666
#  Diff:-  1.7863260383761084
# After ::::
#  EX R Square:-  0.9958548259355052
#  LN R Square:-  0.948140492642622
#  Diff:-  1.5486023849661796
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\22\MOD-PM-00593-5-19.csv
# Before ::::
#  EX R Square:-  0.9831874942694114
#  LN R Square:-  0.9203803092958328
#  Diff:-  3.682726617240272
# After ::::
#  EX R Square:-  0.9831874942694114
#  LN R Square:-  0.9203803092958328
#  Diff:-  3.682726617240272
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\33\MOD-PM-00606-1-26.csv
# Before ::::
#  EX R Square:-  0.8493665380886338
#  LN R Square:-  0.912610149317777
#  Diff:-  0.18242774668378692
# After ::::
#  EX R Square:-  0.9321282753680724
#  LN R Square:-  0.9354158121542971
#  Diff:-  1.0302306244644486
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\33\MOD-PM-00606-12-18.csv
# Before ::::
#  EX R Square:-  0.6565909553254872
#  LN R Square:-  0.6222778225507022
#  Diff:-  0.3124805185983588
# After ::::
#  EX R Square:-  0.8979056245481026
#  LN R Square:-  0.890556318565245
#  Diff:-  0.3884225216301156
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\33\MOD-PM-00606-12-22.csv
# Before ::::
#  EX R Square:-  0.9436564608718251
#  LN R Square:-  0.936421403318522
#  Diff:-  0.7077746687254951
# After ::::
#  EX R Square:-  0.9510918092244554
#  LN R Square:-  0.9655672532559684
#  Diff:-  0.5464856626211319
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\33\MOD-PM-00606-2-23.csv
# Before ::::
#  EX R Square:-  0.9433437047042793
#  LN R Square:-  0.958877945903985
#  Diff:-  1.2175756711910228
# After ::::
#  EX R Square:-  0.9427616944463664
#  LN R Square:-  0.951262156336587
#  Diff:-  0.8197758906320645
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\33\MOD-PM-00606-2-9.csv
# Before ::::
#  EX R Square:-  0.9371957051393263
#  LN R Square:-  0.941147983270362
#  Diff:-  2.1618125125464682
# After ::::
#  EX R Square:-  0.9373227359638643
#  LN R Square:-  0.9630020403616523
#  Diff:-  1.5320443299660047
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\33\MOD-PM-00606-3-09.csv
# Before ::::
#  EX R Square:-  0.9448256450218663
#  LN R Square:-  0.8895079522488408
#  Diff:-  1.4368002959722093
# After ::::
#  EX R Square:-  0.9665725589610171
#  LN R Square:-  0.9470253824563054
#  Diff:-  0.9159055166389996
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\33\MOD-PM-00606-3-10.csv
# Before ::::
#  EX R Square:-  0.9701940443258557
#  LN R Square:-  0.9477166594008648
#  Diff:-  1.6564853370362869
# After ::::
#  EX R Square:-  0.942968862730967
#  LN R Square:-  0.9176257894384028
#  Diff:-  1.410858346764078
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\33\MOD-PM-00606-3-23.csv
# Before ::::
#  EX R Square:-  0.9689855034304716
#  LN R Square:-  0.9316395392516489
#  Diff:-  3.592900334774246
# After ::::
#  EX R Square:-  0.9025961269150853
#  LN R Square:-  0.8920092270313805
#  Diff:-  1.7520217758990322
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\33\MOD-PM-00606-3-24.csv
# Before ::::
#  EX R Square:-  0.9832082301536554
#  LN R Square:-  0.9454299004235505
#  Diff:-  5.277547713528517
# After ::::
#  EX R Square:-  0.9821157895345061
#  LN R Square:-  0.9594344130240164
#  Diff:-  4.356847666889155
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\33\MOD-PM-00606-4-20.csv
# Before ::::
#  EX R Square:-  0.9756572747436106
#  LN R Square:-  0.9490491649333203
#  Diff:-  2.1135247432262667
# After ::::
#  EX R Square:-  0.9704894673055445
#  LN R Square:-  0.9778336740010928
#  Diff:-  1.2337495788407495
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\33\MOD-PM-00606-5-12.csv
# Before ::::
#  EX R Square:-  0.9893979749839323
#  LN R Square:-  0.9493496233395836
#  Diff:-  2.8978198341476658
# After ::::
#  EX R Square:-  0.9893979749839323
#  LN R Square:-  0.9493496233395836
#  Diff:-  2.8978198341476658
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\33\MOD-PM-00606-5-19.csv
# Before ::::
#  EX R Square:-  0.9319366316325607
#  LN R Square:-  0.9672394585597339
#  Diff:-  0.06902287863089818
# After ::::
#  EX R Square:-  0.9203097296825551
#  LN R Square:-  0.9805064589680128
#  Diff:-  0.9578631108291491
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\33\MOD-PM-00606-5-4.csv
# Before ::::
#  EX R Square:-  0.9894682198040663
#  LN R Square:-  0.8490683591630499
#  Diff:-  3.540316116180951
# After ::::
#  EX R Square:-  0.9881054293027481
#  LN R Square:-  0.9883155883001288
#  Diff:-  1.1180807352350737
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\34\MOD-PM-00607-1-27.csv
# Before ::::
#  EX R Square:-  0.9041637040501346
#  LN R Square:-  0.6574231018452253
#  Diff:-  2.1566019539876256
# After ::::
#  EX R Square:-  0.9904575355031335
#  LN R Square:-  0.9924231480505099
#  Diff:-  0.6914804078066119
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\34\MOD-PM-00607-4-20.csv
# Before ::::
#  EX R Square:-  0.805921375392326
#  LN R Square:-  0.7095914920322377
#  Diff:-  2.9035102275019473
# After ::::
#  EX R Square:-  0.805921375392326
#  LN R Square:-  0.7095914920322377
#  Diff:-  2.9035102275019473
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\CBHS\Processed\\34\MOD-PM-00607-5-18.csv
# Before ::::
#  EX R Square:-  0.9424359908400135
#  LN R Square:-  0.7715929741051868
#  Diff:-  4.643248343692016
# After ::::
#  EX R Square:-  0.9445045757892734
#  LN R Square:-  0.9007539234958378
#  Diff:-  3.928085315686331
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\39\MOD-PM-00570-12-05.csv
# Before ::::
#  EX R Square:-  0.9970499831945792
#  LN R Square:-  0.9463254828438178
#  Diff:-  0.07663656520430198
# After ::::
#  EX R Square:-  0.9980473130789171
#  LN R Square:-  0.9981177185133018
#  Diff:-  0.005731064509950146
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\39\MOD-PM-00570-4-20.csv
# Before ::::
#  EX R Square:-  0.9271627184312791
#  LN R Square:-  0.8175041986960374
#  Diff:-  0.26607615840182974
# After ::::
#  EX R Square:-  0.9618693606817289
#  LN R Square:-  0.9278322730553056
#  Diff:-  2.1171764183292865
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\39\MOD-PM-00570-5-18.csv
# Before ::::
#  EX R Square:-  0.9767665163632755
#  LN R Square:-  0.9244424137815168
#  Diff:-  0.31980076337026014
# After ::::
#  EX R Square:-  0.9703380720525385
#  LN R Square:-  0.9795442877163374
#  Diff:-  0.09399461196499292
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\40\MOD-PM-00571-2-10.csv
# Before ::::
#  EX R Square:-  0.9215554976760322
#  LN R Square:-  0.9232275819432495
#  Diff:-  0.02928863468102283
# After ::::
#  EX R Square:-  0.9060414051439157
#  LN R Square:-  0.9125352109168045
#  Diff:-  0.12642916648272418
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\40\MOD-PM-00571-2-24.csv
# Before ::::
#  EX R Square:-  0.9473845986668767
#  LN R Square:-  0.9265101222131858
#  Diff:-  0.18343951922472246
# After ::::
#  EX R Square:-  0.9437222566166013
#  LN R Square:-  0.9416105992607956
#  Diff:-  0.07587538760271251
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\40\MOD-PM-00571-2-9.csv
# Before ::::
#  EX R Square:-  0.9532167565721494
#  LN R Square:-  0.9434161938316684
#  Diff:-  0.08672356099607981
# After ::::
#  EX R Square:-  0.8558537659823899
#  LN R Square:-  0.8609593035704322
#  Diff:-  0.01992838482558601
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\40\MOD-PM-00571-4-06.csv
# Before ::::
#  EX R Square:-  0.9389407682720499
#  LN R Square:-  0.7840334489498612
#  Diff:-  0.3461891789468303
# After ::::
#  EX R Square:-  0.8905111590574136
#  LN R Square:-  0.8673321056655992
#  Diff:-  0.29444547182689784
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\40\MOD-PM-00571-4-07.csv
# Before ::::
#  EX R Square:-  0.7310748795930009
#  LN R Square:-  0.953654161912252
#  Diff:-  2.3254586754234006
# After ::::
#  EX R Square:-  0.6996445109443006
#  LN R Square:-  0.7320865487188333
#  Diff:-  17.864736781642872
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\40\MOD-PM-00571-4-20.csv
# Before ::::
#  EX R Square:-  0.8485858700984842
#  LN R Square:-  0.9139275720957618
#  Diff:-  0.21323931435120935
# After ::::
#  EX R Square:-  0.7728915814975847
#  LN R Square:-  0.8282765577996004
#  Diff:-  0.22121400027992033
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\40\MOD-PM-00571-5-11.csv
# Before ::::
#  EX R Square:-  0.5732506733450158
#  LN R Square:-  0.9285027576168388
#  Diff:-  0.871927090211194
# After ::::
#  EX R Square:-  0.9230672753937453
#  LN R Square:-  0.8952869510295918
#  Diff:-  1.3985806661345173
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\40\MOD-PM-00571-5-12.csv
# Before ::::
#  EX R Square:-  0.9392537689277513
#  LN R Square:-  0.976482317151741
#  Diff:-  0.40418713760226654
# After ::::
#  EX R Square:-  0.9336290664738349
#  LN R Square:-  0.9799541880187854
#  Diff:-  0.3149081689712627
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\40\MOD-PM-00571-5-18.csv
# Before ::::
#  EX R Square:-  0.9246711220064904
#  LN R Square:-  0.9374330343474814
#  Diff:-  0.050174673631034894
# After ::::
#  EX R Square:-  0.9246711220064904
#  LN R Square:-  0.9374330343474814
#  Diff:-  0.050174673631034894
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\40\MOD-PM-00571-5-19.csv
# Before ::::
#  EX R Square:-  0.8808834448653732
#  LN R Square:-  0.9059873340265989
#  Diff:-  3.620174865734034
# After ::::
#  EX R Square:-  0.8776845822484787
#  LN R Square:-  0.8797586424897496
#  Diff:-  3.5227969605288556
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\40\MOD-PM-00571-5-5.csv
# Before ::::
#  EX R Square:-  0.9463065718769369
#  LN R Square:-  0.8880340316986821
#  Diff:-  2.9077601148286396
# After ::::
#  EX R Square:-  0.34698990283188436
#  LN R Square:-  0.38450015110768376
#  Diff:-  1.9635665561222746
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\41\MOD-PM-00608-2-20.csv
# Before ::::
#  EX R Square:-  0.8469883993538109
#  LN R Square:-  0.9544106599846149
#  Diff:-  7.216218783026431
# After ::::
#  EX R Square:-  0.8469883993538109
#  LN R Square:-  0.9544106599846149
#  Diff:-  7.216218783026431
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\41\MOD-PM-00608-2-3.csv
# Before ::::
#  EX R Square:-  0.8878705134205996
#  LN R Square:-  0.9276864042089623
#  Diff:-  0.319965024706784
# After ::::
#  EX R Square:-  0.7842161962213952
#  LN R Square:-  0.7850126925736693
#  Diff:-  0.24917683821905445
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\41\MOD-PM-00608-3-10.csv
# Before ::::
#  EX R Square:-  0.9195428022531871
#  LN R Square:-  0.9827364817134132
#  Diff:-  1.4677809771602366
# After ::::
#  EX R Square:-  0.9087552426382268
#  LN R Square:-  0.9775859748328329
#  Diff:-  1.3597387531609622
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\41\MOD-PM-00608-4-20.csv
# Before ::::
#  EX R Square:-  0.87067964542332
#  LN R Square:-  0.13859069796156365
#  Diff:-  1.5244455779271102
# After ::::
#  EX R Square:-  0.878100928381701
#  LN R Square:-  0.8706853200840998
#  Diff:-  0.10027262939444093
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\41\MOD-PM-00608-5-18.csv
# Before ::::
#  EX R Square:-  0.9411930828740721
#  LN R Square:-  0.7912153199594953
#  Diff:-  0.7771194685498017
# After ::::
#  EX R Square:-  0.6680905750089206
#  LN R Square:-  0.6713009683482294
#  Diff:-  0.37898428351685287
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\42\MOD-PM-00596-2-16.csv
# Before ::::
#  EX R Square:-  0.7529289903302878
#  LN R Square:-  0.8619416546859734
#  Diff:-  0.0646064964425399
# After ::::
#  EX R Square:-  0.7678831811234317
#  LN R Square:-  0.6324944208180336
#  Diff:-  2.5453389885518467
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\42\MOD-PM-00596-2-23.csv
# Before ::::
#  EX R Square:-  0.9434889666661864
#  LN R Square:-  0.9862908097295865
#  Diff:-  0.03354389806269997
# After ::::
#  EX R Square:-  0.8881801150694706
#  LN R Square:-  0.9520735798747143
#  Diff:-  0.05586868641830445
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\42\MOD-PM-00596-2-24.csv
# Before ::::
#  EX R Square:-  0.9346268124463655
#  LN R Square:-  0.9733395061123665
#  Diff:-  0.5953192400398717
# After ::::
#  EX R Square:-  0.924767799117651
#  LN R Square:-  0.9779798695501404
#  Diff:-  0.4620850218181629
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\42\MOD-PM-00596-2-3.csv
# Before ::::
#  EX R Square:-  0.8721894675592851
#  LN R Square:-  0.8790667165884165
#  Diff:-  0.006051968547760023
# After ::::
#  EX R Square:-  0.8721894675592851
#  LN R Square:-  0.8790667165884165
#  Diff:-  0.006051968547760023
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\42\MOD-PM-00596-4-06.csv
# Before ::::
#  EX R Square:-  0.7831641542250414
#  LN R Square:-  0.9367345650612642
#  Diff:-  0.16834112929992495
# After ::::
#  EX R Square:-  0.7035090274720384
#  LN R Square:-  0.8740887779871245
#  Diff:-  0.14924443653364927
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\42\MOD-PM-00596-4-07.csv
# Before ::::
#  EX R Square:-  0.9114830882460383
#  LN R Square:-  0.9788079742235957
#  Diff:-  0.3197904645287206
# After ::::
#  EX R Square:-  0.989257812046469
#  LN R Square:-  0.9925008087851908
#  Diff:-  0.75812296478753
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\42\MOD-PM-00596-5-12.csv
# Before ::::
#  EX R Square:-  0.7458572908587001
#  LN R Square:-  0.8235873965059395
#  Diff:-  1.433983589114804
# After ::::
#  EX R Square:-  0.924670353705464
#  LN R Square:-  0.9499973671877022
#  Diff:-  0.8574135100229192
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\42\MOD-PM-00596-5-18.csv
# Before ::::
#  EX R Square:-  0.8979909117676338
#  LN R Square:-  0.9363720788642446
#  Diff:-  0.13271127330185273
# After ::::
#  EX R Square:-  0.8979909117676338
#  LN R Square:-  0.9363720788642446
#  Diff:-  0.13271127330185273
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\42\MOD-PM-00596-5-19.csv
# Before ::::
#  EX R Square:-  0.8875788557889266
#  LN R Square:-  0.974112783510275
#  Diff:-  0.016663180207494577
# After ::::
#  EX R Square:-  0.9258692309627884
#  LN R Square:-  0.9443417062924416
#  Diff:-  0.5338362940065071
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\42\MOD-PM-00596-5-4.csv
# Before ::::
#  EX R Square:-  0.7234910958361348
#  LN R Square:-  0.7272398568073977
#  Diff:-  0.034401218280442514
# After ::::
#  EX R Square:-  0.7164647894794822
#  LN R Square:-  0.7425333326518462
#  Diff:-  0.04235138555500895
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\43\MOD-PM-00560-2-16.csv
# Before ::::
#  EX R Square:-  0.9138215226916737
#  LN R Square:-  0.9478445992178992
#  Diff:-  0.07831342577414363
# After ::::
#  EX R Square:-  0.8814472071104702
#  LN R Square:-  0.9311241046476597
#  Diff:-  0.07342952181338064
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\43\MOD-PM-00560-2-24.csv
# Before ::::
#  EX R Square:-  0.899688097923264
#  LN R Square:-  0.9629872923240602
#  Diff:-  0.26225693473339984
# After ::::
#  EX R Square:-  0.790752730196773
#  LN R Square:-  0.8909345291317338
#  Diff:-  0.2625049762418048
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\43\MOD-PM-00560-3-10.csv
# Before ::::
#  EX R Square:-  0.8798906942377357
#  LN R Square:-  0.9578408447201933
#  Diff:-  0.2441303556850989
# After ::::
#  EX R Square:-  0.8702044682321408
#  LN R Square:-  0.9512482164018378
#  Diff:-  0.22726232961321857
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\43\MOD-PM-00560-4-06.csv
# Before ::::
#  EX R Square:-  0.8178256841336
#  LN R Square:-  0.9507134716092532
#  Diff:-  0.059046697785300806
# After ::::
#  EX R Square:-  -3.662950284378299
#  LN R Square:-  1.0
#  Diff:-  1464.8272559092964
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\43\MOD-PM-00560-4-07.csv
# Before ::::
#  EX R Square:-  0.765696555219239
#  LN R Square:-  0.9248301268478245
#  Diff:-  3.7322425936125025
# After ::::
#  EX R Square:-  0.7387933809656289
#  LN R Square:-  0.9141708448806696
#  Diff:-  3.2213309045441805
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\43\MOD-PM-00560-4-20.csv
# Before ::::
#  EX R Square:-  0.8869537586599753
#  LN R Square:-  0.9018809022920922
#  Diff:-  0.22161290384913587
# After ::::
#  EX R Square:-  -2.736810883176509
#  LN R Square:-  0.95372966950576
#  Diff:-  1873.222972764778
# C:\Users\vrana7\Anaconda3\lib\site-packages\scipy\optimize\_minpack_py.py:906: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# C:\Users\vrana7\Anaconda3\lib\site-packages\scipy\optimize\_minpack_py.py:906: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\43\MOD-PM-00560-4-21.csv
# Before ::::
#  EX R Square:-  0.8185517851500455
#  LN R Square:-  0.9670648822257987
#  Diff:-  1.6776076412879477
# After ::::
#  EX R Square:-  0.6792200968722368
#  LN R Square:-  0.6870217741451128
#  Diff:-  12.201532262045703
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\43\MOD-PM-00560-5-11.csv
# Before ::::
#  EX R Square:-  0.4857664380321728
#  LN R Square:-  0.9096077018652131
#  Diff:-  0.051806418540091714
# After ::::
#  EX R Square:-  0.34623795017357495
#  LN R Square:-  0.5164595982847103
#  Diff:-  0.3733069660029437
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\43\MOD-PM-00560-5-12.csv
# Before ::::
#  EX R Square:-  0.9461089438121562
#  LN R Square:-  0.9679319651272262
#  Diff:-  1.0385715706091871
# After ::::
#  EX R Square:-  0.9461089438121562
#  LN R Square:-  0.9679319651272262
#  Diff:-  1.0385715706091871
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\43\MOD-PM-00560-5-18.csv
# Before ::::
#  EX R Square:-  0.7069309615167647
#  LN R Square:-  0.8792987659217226
#  Diff:-  0.6171201171164804
# After ::::
#  EX R Square:-  0.7101306980327478
#  LN R Square:-  0.706460701067253
#  Diff:-  0.7005500757376628
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\43\MOD-PM-00560-5-19.csv
# Before ::::
#  EX R Square:-  0.8843873779566087
#  LN R Square:-  0.8998625412196083
#  Diff:-  2.805251264734076
# After ::::
#  EX R Square:-  0.8605641729746217
#  LN R Square:-  0.9487714473201276
#  Diff:-  1.8444548714944995
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\43\MOD-PM-00560-5-5.csv
# Before ::::
#  EX R Square:-  0.9309509286590508
#  LN R Square:-  0.9723832664633912
#  Diff:-  0.3803286492159921
# After ::::
#  EX R Square:-  0.9038485898239926
#  LN R Square:-  0.9559917176324033
#  Diff:-  0.3998561328451746
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\44\MOD-PM-00569-2-10.csv
# Before ::::
#  EX R Square:-  0.9122951495704734
#  LN R Square:-  0.9624834152902813
#  Diff:-  0.05651914420828574
# After ::::
#  EX R Square:-  0.8921656702306701
#  LN R Square:-  0.9334034532791573
#  Diff:-  0.06979519914627821
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\44\MOD-PM-00569-2-16.csv
# Before ::::
#  EX R Square:-  0.9730272098679442
#  LN R Square:-  0.9338090806176631
#  Diff:-  1.287679168335639
# After ::::
#  EX R Square:-  0.9750437247798335
#  LN R Square:-  0.9494899727258634
#  Diff:-  0.919835234732326
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\44\MOD-PM-00569-2-23.csv
# Before ::::
#  EX R Square:-  0.8262757071126716
#  LN R Square:-  0.8180006542637811
#  Diff:-  0.05082219256276377
# After ::::
#  EX R Square:-  0.8262757071126716
#  LN R Square:-  0.8180006542637811
#  Diff:-  0.05082219256276377
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\44\MOD-PM-00569-2-24.csv
# Before ::::
#  EX R Square:-  0.9813750148379998
#  LN R Square:-  0.9298353733536016
#  Diff:-  0.7568001215795312
# After ::::
#  EX R Square:-  0.9847311752133482
#  LN R Square:-  0.9544492334047683
#  Diff:-  0.43932152929400425
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\44\MOD-PM-00569-4-07.csv
# Before ::::
#  EX R Square:-  0.7964636098790552
#  LN R Square:-  0.8958626900620128
#  Diff:-  0.8440205548555957
# After ::::
#  EX R Square:-  0.7836860008595189
#  LN R Square:-  0.8860400911823538
#  Diff:-  0.8414395734937101
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\44\MOD-PM-00569-4-20.csv
# Before ::::
#  EX R Square:-  0.9657424340961911
#  LN R Square:-  0.9388202075269376
#  Diff:-  0.05739213106801605
# After ::::
#  EX R Square:-  0.9512957380994941
#  LN R Square:-  0.954645519669192
#  Diff:-  0.011705129745446574
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\44\MOD-PM-00569-5-12.csv
# Before ::::
#  EX R Square:-  0.9619990153937569
#  LN R Square:-  0.9028018790908919
#  Diff:-  1.0525018885734574
# After ::::
#  EX R Square:-  0.9735325862697773
#  LN R Square:-  0.9267265858483422
#  Diff:-  0.7392770882091078
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\44\MOD-PM-00569-5-18.csv
# Before ::::
#  EX R Square:-  0.6920667107466316
#  LN R Square:-  0.8373634107738384
#  Diff:-  0.43242976763081553
# After ::::
#  EX R Square:-  0.919300290218993
#  LN R Square:-  0.927559568056619
#  Diff:-  0.29530418316308693
# C:\Users\vrana7\Anaconda3\lib\site-packages\scipy\optimize\_minpack_py.py:906: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\44\MOD-PM-00569-5-4.csv
# Before ::::
#  EX R Square:-  0.9333721429130092
#  LN R Square:-  0.8917792156263686
#  Diff:-  1.592255287977249
# After ::::
#  EX R Square:-  0.9333721429130092
#  LN R Square:-  0.8917792156263686
#  Diff:-  1.592255287977249
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\45\MOD-PM-00566-2-16.csv
# Before ::::
#  EX R Square:-  0.9050586983284852
#  LN R Square:-  0.9674957609655814
#  Diff:-  0.43541778041406287
# After ::::
#  EX R Square:-  0.8875787209232633
#  LN R Square:-  0.9758545002892373
#  Diff:-  0.14005380577167514
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\45\MOD-PM-00566-2-24.csv
# Before ::::
#  EX R Square:-  0.7438219496194
#  LN R Square:-  0.8574821573093481
#  Diff:-  0.5921830940267268
# After ::::
#  EX R Square:-  0.6802519383841762
#  LN R Square:-  0.7001200057379374
#  Diff:-  5.303013290927041
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\45\MOD-PM-00566-2-3.csv
# Before ::::
#  EX R Square:-  0.8646630638750499
#  LN R Square:-  0.9431852310135103
#  Diff:-  0.051540348880716125
# After ::::
#  EX R Square:-  0.9996113282196206
#  LN R Square:-  0.9985262897825099
#  Diff:-  1.330062854264483
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\45\MOD-PM-00566-4-06.csv
# Before ::::
#  EX R Square:-  0.8843833712948762
#  LN R Square:-  0.9281714492831756
#  Diff:-  0.58590713502964
# After ::::
#  EX R Square:-  0.8725193995965218
#  LN R Square:-  0.8586467192522373
#  Diff:-  0.4743041537548993
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\45\MOD-PM-00566-4-20.csv
# Before ::::
#  EX R Square:-  0.9433616327980762
#  LN R Square:-  0.8573560979491084
#  Diff:-  0.6704759544705271
# After ::::
#  EX R Square:-  0.9707307951620072
#  LN R Square:-  0.9020223724659245
#  Diff:-  0.35110424967995946
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\45\MOD-PM-00566-5-11.csv
# Before ::::
#  EX R Square:-  0.9121194238231424
#  LN R Square:-  0.8765266094954265
#  Diff:-  0.9360784575930748
# After ::::
#  EX R Square:-  0.917165715987282
#  LN R Square:-  0.8600795320301022
#  Diff:-  0.7497468237250298
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\45\MOD-PM-00566-5-4.csv
# Before ::::
#  EX R Square:-  0.6535245517215389
#  LN R Square:-  0.5591066716909322
#  Diff:-  0.21821253700914722
# After ::::
#  EX R Square:-  0.851992858230194
#  LN R Square:-  0.8152941077797619
#  Diff:-  0.3667010462436684
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\46\MOD-PM-00567-2-16.csv
# Before ::::
#  EX R Square:-  0.017273497727991693
#  LN R Square:-  1.0243727717296203e-05
#  Diff:-  0.9782249385406849
# After ::::
#  EX R Square:-  0.9664094712499341
#  LN R Square:-  0.9230581554767667
#  Diff:-  3.243472293175273
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\46\MOD-PM-00567-2-22.csv
# Before ::::
#  EX R Square:-  0.9415666953893644
#  LN R Square:-  0.9517381474269592
#  Diff:-  3.0701501526686643
# After ::::
#  EX R Square:-  0.9369961094042545
#  LN R Square:-  0.9312567552011425
#  Diff:-  2.7911444612886305
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\46\MOD-PM-00567-2-23.csv
# Before ::::
#  EX R Square:-  0.8250242339934492
#  LN R Square:-  0.9548193113180954
#  Diff:-  0.04639382049138446
# After ::::
#  EX R Square:-  0.7907627484688078
#  LN R Square:-  0.787230889250851
#  Diff:-  2.574654709571929
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\46\MOD-PM-00567-2-3.csv
# Before ::::
#  EX R Square:-  0.925157263667289
#  LN R Square:-  0.9323025236121707
#  Diff:-  0.0860461318158593
# After ::::
#  EX R Square:-  0.925157263667289
#  LN R Square:-  0.9323025236121707
#  Diff:-  0.0860461318158593
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\46\MOD-PM-00567-4-06.csv
# Before ::::
#  EX R Square:-  0.4731241477751338
#  LN R Square:-  0.7573548983988678
#  Diff:-  0.0035514698895050545
# After ::::
#  EX R Square:-  0.9274748753196219
#  LN R Square:-  0.904360550360064
#  Diff:-  0.05164272114350865
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\46\MOD-PM-00567-4-07.csv
# Before ::::
#  EX R Square:-  0.6281825688526967
#  LN R Square:-  0.6131203950876767
#  Diff:-  0.12945601106747306
# After ::::
#  EX R Square:-  0.9728695947087039
#  LN R Square:-  0.9611872275592452
#  Diff:-  0.09457458850783729
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\46\MOD-PM-00567-4-20.csv
# Before ::::
#  EX R Square:-  0.8048292891023353
#  LN R Square:-  0.812640345158616
#  Diff:-  0.03840665657013835
# After ::::
#  EX R Square:-  0.8289828072582471
#  LN R Square:-  0.8327270519518107
#  Diff:-  0.11831595113939208
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\46\MOD-PM-00567-5-11.csv
# Before ::::
#  EX R Square:-  0.8986240246155992
#  LN R Square:-  0.8990712960567889
#  Diff:-  0.053452223807362975
# After ::::
#  EX R Square:-  0.797242557723861
#  LN R Square:-  0.8598269924686659
#  Diff:-  0.043580920928526556
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\46\MOD-PM-00567-5-12.csv
# Before ::::
#  EX R Square:-  0.8343330608894042
#  LN R Square:-  0.9506565764540453
#  Diff:-  0.19223703217798027
# After ::::
#  EX R Square:-  0.8343330608894042
#  LN R Square:-  0.9506565764540453
#  Diff:-  0.19223703217798027
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\46\MOD-PM-00567-5-18.csv
# Before ::::
#  EX R Square:-  0.8415009765901782
#  LN R Square:-  0.8506083654178962
#  Diff:-  0.09114034668201249
# After ::::
#  EX R Square:-  0.8657563829709851
#  LN R Square:-  0.8148434133784725
#  Diff:-  0.07923744503093821
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\46\MOD-PM-00567-5-19.csv
# Before ::::
#  EX R Square:-  0.7218683716173393
#  LN R Square:-  0.8167913530266708
#  Diff:-  0.11951199780973953
# After ::::
#  EX R Square:-  0.8066289658897513
#  LN R Square:-  0.8020277716459117
#  Diff:-  0.7179358071951665
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\47\MOD-PM-00576-2-23.csv
# Before ::::
#  EX R Square:-  0.8786200589514189
#  LN R Square:-  0.943402643071377
#  Diff:-  0.289534646399385
# After ::::
#  EX R Square:-  0.8649278360723266
#  LN R Square:-  0.9283483774366936
#  Diff:-  0.28482428490145517
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\47\MOD-PM-00576-4-06.csv
# Before ::::
#  EX R Square:-  0.7940129941425771
#  LN R Square:-  0.8619801634128545
#  Diff:-  0.9790645578828983
# After ::::
#  EX R Square:-  0.7842571180642233
#  LN R Square:-  0.8055598062574646
#  Diff:-  0.8730929738151391
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\47\MOD-PM-00576-4-20.csv
# Before ::::
#  EX R Square:-  0.7874054671494277
#  LN R Square:-  0.8398139682179085
#  Diff:-  0.1445464448086567
# After ::::
#  EX R Square:-  0.811330016768282
#  LN R Square:-  0.8267833795095592
#  Diff:-  0.1593402822240721
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\47\MOD-PM-00576-5-11.csv
# Before ::::
#  EX R Square:-  0.5818316062104828
#  LN R Square:-  0.8484476070371101
#  Diff:-  0.5796740831079552
# After ::::
#  EX R Square:-  0.554238879109602
#  LN R Square:-  0.8195073884844999
#  Diff:-  0.5848993270870918
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\47\MOD-PM-00576-5-19.csv
# Before ::::
#  EX R Square:-  0.9408394872411229
#  LN R Square:-  0.9370681079010761
#  Diff:-  0.43064277856545674
# After ::::
#  EX R Square:-  0.9166665449191873
#  LN R Square:-  0.9037531337415557
#  Diff:-  1.6530053307535368
#
# C:\Users\vrana7\Documents\CIA\Humidifier-Experiment\RDRK\Processed\\47\MOD-PM-00576-5-5.csv
# Before ::::
#  EX R Square:-  0.9785996953604543
#  LN R Square:-  0.9356596200934281
#  Diff:-  1.2824161753898666
# After ::::
#  EX R Square:-  0.9818003085046407
#  LN R Square:-  0.9500546170974179
#  Diff:-  0.9654360886136284

# %%
files = [
    'C:\\Users\\vrana7\\Documents\\CIA\\Humidifier-Experiment\\RDRK\\Processed\\45\\MOD-PM-00566-2-3.csv',
    'C:\\Users\\vrana7\\Documents\\CIA\\Humidifier-Experiment\\RDRK\\Processed\\45\\MOD-PM-00566-2-16.csv',
   
    'C:\\Users\\vrana7\\Documents\\CIA\\Humidifier-Experiment\\RDRK\\Processed\\45\\MOD-PM-00566-2-23.csv',
    'C:\\Users\\vrana7\\Documents\\CIA\\Humidifier-Experiment\\RDRK\\Processed\\45\\MOD-PM-00566-2-24.csv',
    
    'C:\\Users\\vrana7\\Documents\\CIA\\Humidifier-Experiment\\RDRK\\Processed\\45\\MOD-PM-00566-3-09.csv',
    'C:\\Users\\vrana7\\Documents\\CIA\\Humidifier-Experiment\\RDRK\\Processed\\45\\MOD-PM-00566-3-10.csv',
    
    'C:\\Users\\vrana7\\Documents\\CIA\\Humidifier-Experiment\\RDRK\\Processed\\45\\MOD-PM-00566-3-23.csv',
    'C:\\Users\\vrana7\\Documents\\CIA\\Humidifier-Experiment\\RDRK\\Processed\\45\\MOD-PM-00566-3-24.csv',
    
    'C:\\Users\\vrana7\\Documents\\CIA\\Humidifier-Experiment\\RDRK\\Processed\\45\\MOD-PM-00566-4-06.csv',
    'C:\\Users\\vrana7\\Documents\\CIA\\Humidifier-Experiment\\RDRK\\Processed\\45\\MOD-PM-00566-4-07.csv',
    
    'C:\\Users\\vrana7\\Documents\\CIA\\Humidifier-Experiment\\RDRK\\Processed\\45\\MOD-PM-00566-4-20.csv',
    'C:\\Users\\vrana7\\Documents\\CIA\\Humidifier-Experiment\\RDRK\\Processed\\45\\MOD-PM-00566-4-21.csv',
    
    'C:\\Users\\vrana7\\Documents\\CIA\\Humidifier-Experiment\\RDRK\\Processed\\45\\MOD-PM-00566-5-4.csv',
    'C:\\Users\\vrana7\\Documents\\CIA\\Humidifier-Experiment\\RDRK\\Processed\\45\\MOD-PM-00566-5-5.csv',
    
    'C:\\Users\\vrana7\\Documents\\CIA\\Humidifier-Experiment\\RDRK\\Processed\\45\\MOD-PM-00566-5-11.csv',
    'C:\\Users\\vrana7\\Documents\\CIA\\Humidifier-Experiment\\RDRK\\Processed\\45\\MOD-PM-00566-5-12.csv',
    
    'C:\\Users\\vrana7\\Documents\\CIA\\Humidifier-Experiment\\RDRK\\Processed\\45\\MOD-PM-00566-5-18.csv',
    'C:\\Users\\vrana7\\Documents\\CIA\\Humidifier-Experiment\\RDRK\\Processed\\45\\MOD-PM-00566-5-19.csv',   
]

dates = [
    '2-3',
    '2-16',
    '2-23',
    '2-24',
    '3-9',
    '3-10',
    '3-23',
    '3-24',
    '4-6',
    '4-7',
    '4-20',
    '4-21',
    '5-4',
    '5-5',
    '5-11',
    '5-12',
    '5-18',
    '5-19'
]

cr = [ '12-23', '1-13', '1-27', '2-10', '2-24', '3-10', '3-24', '4-7','4-21','4-28', '5-5', '5-12','5-19', '2-16', '2-20', '2-22' ]

ex_ach_list = []
ln_ach_list = []
ex_r_list = []
ln_r_list = []
date_list = []

ex_ach_list_w = []
ln_ach_list_w = []
ex_r_list_w = []
ln_r_list_w = []
date_list_w = []
for index,file in enumerate(files):
    if os.path.exists(file):
        print('File name:- ', file.split('\\')[-1])
        exACH,exR,lnACH,lnR = exponetial_fit(file,'ID-45 D-'+dates[index])
        
        if dates[index] in cr:
            ex_ach_list.append(exACH)
            ln_ach_list.append(lnACH)
            ex_r_list.append(exR)
            ln_r_list.append(lnR)
            date_list.append(dates[index])
        else: 
            ex_ach_list_w.append(exACH)
            ln_ach_list_w.append(lnACH)
            ex_r_list_w.append(exR)
            ln_r_list_w.append(lnR)
            date_list_w.append(dates[index])
    else:
        print('************************************************************************')
        print('Path not exits:- ', file.split('\\')[-1])
        print('************************************************************************')

data = {
  'ID' : [47 for i in range(len(ex_ach_list))],
  'ACH Exponetial Fit' : [abs(number) for number in ex_ach_list] ,
  'R Sqaure Ex' : ex_r_list,
  'ACH Linear Fir' : [abs(number) for number in ln_ach_list],
  'R Square Ln' : ln_r_list,
  'date_list' : date_list  
} 

data_w = {
  'ID' : [47 for i in range(len(ex_ach_list_w))],
  'ACH Exponetial Fit' : [abs(number) for number in ex_ach_list_w],
  'R Sqaure Ex' : ex_r_list_w,
  'ACH Linear Fir' : [abs(number) for number in ln_ach_list_w],
  'R Square Ln' : ln_r_list_w,
  'date_list' : date_list_w  
} 

# df = pd.DataFrame(data)
# df_w = pd.DataFrame(data_w)

# if os.path.exists('C-R ACH.csv'):
#     cr_ach = pd.read_csv('C-R ACH.csv')
# else:
#     cr_ach = pd.DataFrame()
# merged_df = pd.concat([cr_ach,df], axis=0)
# merged_df.to_csv('C-R ACH.csv',index=False)

# if os.path.exists('ACH.csv'):
#     ach = pd.read_csv('ACH.csv')
# else:
#     ach = pd.DataFrame()

# merged_df = pd.concat([ach,df_w], axis=0)
# merged_df.to_csv('ACH.csv',index=False)

# %%
folder = 'C:\\Users\\vrana7\\Documents\\CIA\\Humidifier-Experiment\\CBHS\\Processed\\'


subfolders = [f for f in os.listdir(folder) if os.path.isdir(os.path.join(folder, f))]

def save_plot_as_image(time_column, pm25_column, fitted_pm25, params, filename,path):
    plt.figure(figsize=(10, 6))
    plt.scatter(time_column, pm25_column, label='Original Data')
    plt.plot(time_column, fitted_pm25, label='Fitted Curve', color='red')
    plt.xlabel('Time')
    plt.ylabel('PM 2.5')
    plt.title('Fitted Curve of PM 2.5 Data ' + filename)
    plt.legend()
    image_path = f"{path}\\{filename}.png"
    plt.savefig(image_path)
    plt.close()
    return image_path

for subfolder in subfolders:
    path = folder + '\\' +subfolder 
    files = [f for f in os.listdir(path) if f.lower().endswith(('.csv'))]
    for file in files:
        date = file.split('-')[3] + '-' + file.split('-')[4].split('.')[0] + ('-2023' if file.split('-')[3] != '12' else '-2022')
        image_name = 'ID - {} Date - {}'.format(subfolder, date) 
        df = pd.read_csv(path+'\\'+file)
        
        
        time_column = df['Time In Hour']
        pm25_column = df['PM 2.5']
        ln_pm25_column = df['LN(PM 2.5)']

        # Perform curve fitting using curve_fit
        params, covariance = curve_fit(exponential_function, time_column, pm25_column)
        params_l, covariance_l = curve_fit(linear_function, time_column, ln_pm25_column)

        # Calculate the fitted values using the obtained parameters
        fitted_pm25 = exponential_function(time_column, *params)
        liner_fiited_pm25 = linear_function(time_column, *params_l)

        save_plot_as_image(time_column,pm25_column,fitted_pm25,params,image_name, 'Exponential')
        save_plot_as_image(time_column,ln_pm25_column,liner_fiited_pm25,params_l,image_name, 'Linear')

# %%
import pandas as pd

# Assuming df is your DataFrame and 'column_name' is the column you're interested in
# You can replace these with your actual DataFrame and column name
# For this example, let's say the tolerance is 10% for changes

df = pd.DataFrame({'column_name': [100, 90, 80, 90, 60, 50, 30]})

df['PercentageChange'] = df['column_name'].pct_change() * 100

tolerance = 10  # Define the percentage tolerance

# Checking if the percentage change is within the tolerance range
# Start iterating from the second row to avoid NaN values affecting the result
df['WithinTolerance'] = (df['PercentageChange'].shift(-1) <= tolerance) | df['PercentageChange'].isna()

print(df)

index_to_slice = df[df['WithinTolerance'] == False].index[0]

# Slice the column to consider only values from index 0 to the index_to_slice
sliced_column = df.loc[:index_to_slice, 'column_name']

print(sliced_column)
# Out:
#    column_name  PercentageChange  WithinTolerance
# 0          100               NaN             True
# 1           90        -10.000000             True
# 2           80        -11.111111            False
# 3           90         12.500000             True
# 4           60        -33.333333             True
# 5           50        -16.666667             True
# 6           30        -40.000000            False
# 0    100
# 1     90
# 2     80
# Name: column_name, dtype: int64

# %%
# Assuming df is your DataFrame and 'column_name' is the column you're interested in
# You can replace these with your actual DataFrame and column name
# For this example, let's say the tolerance is 10% for changes

df = pd.DataFrame({'column_name': [100,90,80,90,60,50,30]})

df['PercentageChange'] = df['column_name'].pct_change() * 100

tolerance = 10  # Define the percentage tolerance

# Checking if the percentage change is within the tolerance range
# We use abs() to consider both positive and negative changes
df['WithinTolerance'] = df['PercentageChange'] <= tolerance

print(df)

index_to_slice = df[df['WithinTolerance'] == False &  (df['PercentageChange'].isna())].index[0]

# Slice the column to consider only values from index 0 to the index_to_slice
sliced_column = df.loc[:index_to_slice, 'column_name']

print(sliced_column)
# Out:
#   File "C:\Users\vrana7\AppData\Local\Temp\ipykernel_6772\1047808473.py", line 17
#     index_to_slice = df[df['WithinTolerance'] == False &  (! df['PercentageChange'].isna())].index[0]
#                                                            ^
# SyntaxError: invalid syntax
